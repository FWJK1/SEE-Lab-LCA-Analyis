# %% [markdown]
# # Setup
# ## Import and git root

# %%
import bw2io as bi
import bw2data as bd
import bw2calc as bc
import git


from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib as mpl
import re

# %%
def get_git_root():
    repo = git.Repo(search_parent_directories=True)
    return repo.git.rev_parse("--show-toplevel")
root = get_git_root()

# %% [markdown]
# ## Brightway reference variables

# %%
bd.projects.set_current('SEE_LAB')

# %%
bd.databases
# Out:
# Databases dictionary with 5 object(s):
# 	Water bottle LCA
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ecoinvent-3.9.1-biosphere
# 	ecoinvent-3.9.1-cutoff

# %% [markdown]
# # Technosphere Exploration
# ## Brightway (pre-existing)

# %%
eidb = bd.Database("ecoinvent-3.11-cutoff")
eidb.graph_technosphere()

# %% [markdown]
# What this graphed technosphere means:
#
# * Rox of pixels represent inputs to processes
# * Columns of pixels represent outputs from processes
# * (colors) represent the flow of materials, energy, or emissions between them.

# %%
random_act = eidb.random()
random_act.as_dict()
# Out:
# {'comment': "This is a renaming activity. Its purpose is to link 'electric arc furnace slag' to the 'market for electric arc furnace slag, for recovery'. This represents the share of electric arc furnace slag that is recovered for use via internal (in iron and steelmaking) or external routes (e.g. cement making).Through this renaming, the by-product classification of the electric arc furnace slag is changed from 'waste' to 'recyclable material'.\nIncluded activities start:  Activity starts with the reception of 'electric arc furnace slag'.\nIncluded activities end:  Activity ends with the 'electric arc furnace slag, for recovery' being ready for transportation.",
#  'classifications': [('ISIC rev.4 ecoinvent',
#    '3821:Treatment and disposal of non-hazardous waste'),
#   ('CPC',
#    '39310: Slag, dross, scalings and other waste from the manufacture of iron or steel')],
#  'activity type': 'ordinary transforming activity',
#  'activity': 'cb31ca46-0bb6-5c67-95a9-a1eae35052b8',
#  'database': 'ecoinvent-3.11-cutoff',
#  'filename': 'cb31ca46-0bb6-5c67-95a9-a1eae35052b8_6e74937e-b691-4c49-9b8f-5ba44d7c081d.spold',
#  'location': 'RoW',
#  'name': 'electric arc furnace slag to market for electric arc furnace slag, for recovery',
#  'synonyms': [],
#  'parameters': [],
#  'authors': {'data entry': {'name': 'Avraam Symeonidis',
#    'email': 'Symeonidis@ecoinvent.org'},
#   'data generator': {'name': 'Avraam Symeonidis',
#    'email': 'Symeonidis@ecoinvent.org'}},
#  'type': 'process',
#  'reference product': 'electric arc furnace slag',
#  'flow': '6e74937e-b691-4c49-9b8f-5ba44d7c081d',
#  'unit': 'kilogram',
#  'production amount': -1.0,
#  'code': '4363bd5b0c7a82ef4dfd544078c52c77',
#  'id': 55989}

# %%
for exc in random_act.exchanges():
    print(exc)
# Out:
# Exchange: -1.0 kilogram 'electric arc furnace slag to market for electric arc furnace slag, for recovery' (kilogram, RoW, None) to 'electric arc furnace slag to market for electric arc furnace slag, for recovery' (kilogram, RoW, None)>
# Exchange: -1.0 kilogram 'electric arc furnace slag, for recovery, Recycled Content cut-off' (kilogram, GLO, None) to 'electric arc furnace slag to market for electric arc furnace slag, for recovery' (kilogram, RoW, None)>

# %%
[exc for exc in random_act.exchanges()][0].as_dict()
# Out:
# {'flow': '6e74937e-b691-4c49-9b8f-5ba44d7c081d',
#  'type': 'production',
#  'name': 'electric arc furnace slag',
#  'classifications': {'CPC': ['39310: Slag, dross, scalings and other waste from the manufacture of iron or steel']},
#  'production volume': 51800000000.0,
#  'properties': {'aluminium content': {'amount': 0.04321608040201,
#    'comment': "The value of 'aluminium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'antimony content': {'amount': 4.02010050251256e-06,
#    'comment': "The value of 'antimony content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'arsenic content': {'amount': 1.26633165829146e-06,
#    'comment': "The value of 'arsenic content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'barium content': {'amount': 0.00109547738693467,
#    'comment': "The value of 'barium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'beryllium content': {'amount': 1.10552763819096e-06,
#    'comment': "The value of 'beryllium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'cadmium content': {'amount': 7.63819095477387e-06,
#    'comment': "The value of 'cadmium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'calcium content': {'amount': 0.244221105527638,
#    'comment': "The value of 'calcium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'carbon allocation': {'amount': 0.00412, 'unit': 'kg'},
#   'carbon content': {'amount': 0.00414070351758794, 'unit': 'dimensionless'},
#   'carbon content, fossil': {'amount': 0.00414070351758794,
#    'comment': "The value of 'carbon content, fossil' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'carbon content, non-fossil': {'amount': 0.0,
#    'comment': "The value of 'carbon content, non-fossil' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'chromium content': {'amount': 0.0116582914572864,
#    'comment': "The value of 'chromium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'cobalt content': {'amount': 4.82412060301508e-06,
#    'comment': "The value of 'cobalt content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'copper content': {'amount': 0.00110552763819095,
#    'comment': "The value of 'copper content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'dry mass': {'amount': 0.995,
#    'comment': "The value of 'dry mass' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'kg'},
#   'fluorine content': {'amount': 0.0201005025125628,
#    'comment': "The value of 'fluorine content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'heating value, net': {'amount': 0.0,
#    'comment': 'Non combustible products are assumed to have an LHV equal to zero (0).',
#    'unit': 'MJ'},
#   'iron content': {'amount': 0.0985929648241206,
#    'comment': "The value of 'iron content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'lead content': {'amount': 0.000810050251256281,
#    'comment': "The value of 'lead content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'magnesium content': {'amount': 0.0431155778894472,
#    'comment': "The value of 'magnesium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'manganese content': {'amount': 0.0244221105527638,
#    'comment': "The value of 'manganese content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'mercury content': {'amount': 4.02010050251256e-08,
#    'comment': "The value of 'mercury content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'molybdenum content': {'amount': 0.000507537688442211,
#    'comment': "The value of 'molybdenum content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'nickel content': {'amount': 0.000533668341708543,
#    'comment': "The value of 'nickel content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'oxygen content': {'amount': 0.400946532663317,
#    'comment': "The value of 'oxygen content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'phosphorus content': {'amount': 0.00201005025125628,
#    'comment': "The value of 'phosphorus content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'potassium content': {'amount': 0.00355778894472362,
#    'comment': "The value of 'potassium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'price': {'amount': 0.0,
#    'comment': 'Waste products are assigned a price of zero as they are assumed to require further treatment.',
#    'unit': 'EUR2005'},
#   'selenium content': {'amount': 1.80904522613065e-05,
#    'comment': "The value of 'selenium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'silicon content': {'amount': 0.0912562814070352,
#    'comment': "The value of 'silicon content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'silver content': {'amount': 8.44221105527638e-06,
#    'comment': "The value of 'silver content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'sodium content': {'amount': 0.00132663316582915,
#    'comment': "The value of 'sodium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'sulfur content': {'amount': 0.00126633165829146,
#    'comment': "The value of 'sulfur content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'thallium content': {'amount': 1.10552763819095e-05,
#    'comment': "The value of 'thallium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'tin content': {'amount': 1.00502512562814e-05,
#    'comment': "The value of 'tin content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'titanium content': {'amount': 0.00359798994974874,
#    'comment': "The value of 'titanium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'vanadium content': {'amount': 0.00136683417085427,
#    'comment': "The value of 'vanadium content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'water content': {'amount': 0.0050251256281407,
#    'comment': "The value of 'water content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'},
#   'water in wet mass': {'amount': 0.005,
#    'comment': "The value of 'water in wet mass' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'kg'},
#   'wet mass': {'amount': 1.0,
#    'comment': "The value of 'wet mass' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'kg'},
#   'zinc content': {'amount': 0.00108542713567839,
#    'comment': "The value of 'zinc content' is documented in Turner & Symeonidis, 2020.\n Reference: Turner David & Symeonidis Avraam, 2020, Life cycle inventories of the treatment of iron and steelmaking by-products, ecoinvent association, Zürich, Switzerland",
#    'unit': 'dimensionless'}},
#  'activity': 'cb31ca46-0bb6-5c67-95a9-a1eae35052b8',
#  'unit': 'kilogram',
#  'comment': None,
#  'variable name': 'RP',
#  'amount': -1.0,
#  'uncertainty type': 0,
#  'loc': -1.0,
#  'input': ('ecoinvent-3.11-cutoff', '4363bd5b0c7a82ef4dfd544078c52c77'),
#  'output': ('ecoinvent-3.11-cutoff', '4363bd5b0c7a82ef4dfd544078c52c77')}

# %% [markdown]
# ## Original (trivial)
# ### Process Counts
# #### Cleaning and Merging
# First we'll look at all the technosphere processes

# %%
## Create a dictionary of all the country codes counts (from the technosphere activities) and convert to a dataframe
global_dict = defaultdict(int)
for act in eidb:
    cc_code = act['location']
    global_dict[cc_code] += 1

country_frame  = pd.DataFrame(list(global_dict.items()), columns=['Country', 'Process Count'])
country_frame
# Out:
#     Country  Process Count
# 0        BR            312
# 1       GLO           4543
# 2       RoW           4673
# 3        SK             99
# 4        PE            177
# ..      ...            ...
# 327  NORDEL              2
# 328   IN-DD              1
# 329   US-SD              2
# 330     WEU              1
# 331      RW              1
#
# [332 rows x 2 columns]

# %% [markdown]
# We want to look at these as a map; this requires:
# * shapefiles for each country region (eg a global shapefile with provinces included)
# * a dictionary or map to get from each country code to each shapefile
#
# Luckily, (if perhaps a bit oddly), the biosphere has no location detail built in. So we can just ignore it for this analysis.
#
#
# Also luckily, the database overview has a geographies sheet to match what this includes. We merge this now.

# %%
geographies = pd.read_excel(f"{root}/Data/Database-Overview-for-ecoinvent-v3.10_29.04.24.xlsx", sheet_name="Geographies")
country_frame = pd.merge(
    left=country_frame,
    right=geographies,
    how='inner',
    left_on='Country',
    right_on='Shortname'
)

## Clean the frame a bit further. 
country_frame.drop(columns='Country', inplace=True)
country_frame.sort_values(by='Process Count', ascending=False).head(10)
# Out:
#     Process Count                                    ID  \
# 2            4673  7846b897-7c04-4f9f-b607-2b83fcd9a74c
# 1            4543  34dbbff8-88ce-11de-ad60-0019e336be3a
# 9            2710  131278d6-7d7e-11de-9ae2-0019e336be3a
# 6            2272  0723d252-7e2a-11de-9820-0019e336be3a
# 8             620  f9221622-cc45-11de-98ed-0019e336be3a
# 13            422  0c40fa1e-7d7e-11de-9ae2-0019e336be3a
# 28            420  868a66d1-7428-4ba2-9125-253b07afc119
# 15            326  13d387f6-7d7e-11de-9ae2-0019e336be3a
# 0             312  0a2c8c66-7d7e-11de-9ae2-0019e336be3a
# 7             297  12b21766-7d7e-11de-9ae2-0019e336be3a
#
#                           Name                   Shortname   Latitude  \
# 2                Rest-of-World                         RoW        NaN
# 1                       Global                         GLO        NaN
# 9                  Switzerland                          CH  46.861000
# 6                       Europe                         RER  59.970128
# 8   Europe without Switzerland  Europe without Switzerland  48.597508
# 13                       China                          CN  33.420000
# 28              Canada, Québec                       CA-QC  53.390446
# 15    United States of America                          US  39.622000
# 0                       Brazil                          BR -10.772000
# 7                 South Africa                          ZA -30.558000
#
#      Longitude Geography Classification  \
# 2          NaN    ecoinvent Custom Area
# 1          NaN                    World
# 9     7.908000                  Country
# 6    78.961769         ecoinvent Region
# 8     6.421103    ecoinvent Custom Area
# 13  106.514000                  Country
# 28  -71.755869        Province or State
# 15  -98.606000                  Country
# 0   -53.089000                  Country
# 7    23.121000                  Country
#
#                 Contained and Overlapping Geographies
# 2                                                 NaN
# 1   AD; AE; AF; AG; AI; Akrotiri; AL; AM; AO; AQ; ...
# 9                                                 NaN
# 6   AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 8   AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 13  China w/o Inner Mongol; CN-AH; CN-BJ; CN-CCG; ...
# 28                                                NaN
# 15  MRO; NPCC; US-AK; US-AL; US-AR; US-ASCC; US-AZ...
# 0   BR-AC; BR-AL; BR-AM; BR-AP; BR-BA; BR-CE; BR-D...
# 7                                                 NaN

# %% [markdown]
# Explore the distribution a little

# %%
top5 = country_frame.sort_values(by='Process Count', ascending=False).head(6).copy()

plt.figure(figsize=(8, 6))
ax = sns.boxplot(data=country_frame, y='Process Count')

for i, outlier in top5.iterrows():
    plt.text(0, outlier['Process Count'], f"{outlier['Name']}: {outlier['Process Count']}", color='red', ha='center')

plt.title("Basic Boxplot for Ecoinvent globalization")
plt.show()

# %%
plt.figure(figsize=(8, 6))
country_frame['Log Process Count'] = np.log10(country_frame['Process Count'] + 1) 
top5 = country_frame.sort_values(by='Process Count', ascending=False).head(6).copy()

ax = sns.boxplot(data=country_frame, y='Log Process Count')

for i, outlier in top5.iterrows():
    plt.text(0, outlier['Log Process Count'], f"{outlier['Name']}: {outlier['Process Count']}", color='red', ha='center')

plt.title("Basic Boxplot for Ecoinvent globalization")
plt.show()

# %% [markdown]
# Note that:
#
# * Global means global average production -- it **always** means that.
# * Rest of World (RoW) means all the activites NOT explicitly locally defined. For example, if you have Switzerland and USA, than RoW means the global average minus those countries (from both numerator and denominator). Importantly, this means that RoW is **different** for every process (because they have different amounts of regional data).
# * RoW values are not included if the regional values leave <.5% of the global production volume.
#
# This means that in order to map RoW accurately we'd have to 'subtract' the process values we have (for that process). Luckily, at present, this seems like it wouldn't be that useful.
# Source: https://support.ecoinvent.org/geographies
#
#
#
#
# Note also that there are lots of non-country codes in here. Either like RoW on a smaller scale (eg, Europe without Switzerland), or other micro-regions defined by ecoquery or other organizations. For example, a regional electrical grid. In an effort to fix this, we'll have to do some parsing to try to get all the contained geographies in a machine readable format (here, ISO two letter country codes).

# %%
## functions for processing df rows
def get_basename(text):
    text = str(text)
    if len(text) == 2:
        return text
    
    # get the country code from the name, if it makes sense to (written in the XX- format, eg, US-CA for Caliifornia)
    match = re.search(r"..-", text) 
    return match.group(0)[:2] if match else None

def get_basenames(text):
    text = str(text)
    return [get_basename(item.strip()) for item in text.split(";")]

## create a column from the basename, and another  that lists all the contained geogrpahies in our ISO indexable format
country_frame['base_name'] = country_frame['Shortname'].apply(get_basename)
country_frame.sort_values(by='Process Count', ascending=False).head(10)


country_frame['Contained_Geographies_List'] = country_frame['Contained and Overlapping Geographies'].apply(get_basenames)


## check out the frame, looking at the largest once that have a contained geography
country_frame.dropna(subset=['Contained and Overlapping Geographies']).sort_values(by='Process Count', ascending=False).head(25)
# Out:
#      Process Count                                    ID  \
# 1             4543  34dbbff8-88ce-11de-ad60-0019e336be3a
# 6             2272  0723d252-7e2a-11de-9820-0019e336be3a
# 8              620  f9221622-cc45-11de-98ed-0019e336be3a
# 13             422  0c40fa1e-7d7e-11de-9ae2-0019e336be3a
# 15             326  13d387f6-7d7e-11de-9ae2-0019e336be3a
# 0              312  0a2c8c66-7d7e-11de-9ae2-0019e336be3a
# 31             268  0e6a7860-7d7e-11de-9ae2-0019e336be3a
# 56             170  12ea642c-7d7e-11de-9ae2-0019e336be3a
# 25             117  12143bfe-7d7e-11de-9ae2-0019e336be3a
# 16             107  0fecb5e8-7e2a-11de-9820-0019e336be3a
# 106            103  0b2a8a96-7d7e-11de-9ae2-0019e336be3a
# 47              84  0cf950f0-7d7e-11de-9ae2-0019e336be3a
# 44              80  09b1a988-7d7e-11de-9ae2-0019e336be3a
# 176             38  f37ced82-5df8-48c2-a207-1e36dd11a112
# 111             35  a7b38401-afb6-4130-86f6-cd5184c6c40e
# 174             35  50f826e7-ab13-444e-987b-180701b691c9
# 215             34  19c7cdd2-e590-11de-9dfe-0019e336be3a
# 97              32  854cdfab-82bf-4c25-8515-ba33589d3efe
# 166             32  42e6cfaf-ffa3-4f42-85bb-55e1b1c40c56
# 164             31  09db3260-7e2a-11de-9820-0019e336be3a
# 237             31  b7fcfda9-0add-49aa-87d4-d60f3bda4283
# 45              31  6432879f-dc31-4e80-bc55-573f72dafee8
# 48              26  598f9aa4-e409-11de-bce5-0019e336be3a
# 98              25  a9c3be27-affe-464c-8ebf-996d8ab6a958
# 81              22  dd2330a8-30dc-4af9-bb3a-d2d2bf404dde
#
#                                                   Name  \
# 1                                               Global
# 6                                               Europe
# 8                           Europe without Switzerland
# 13                                               China
# 15                            United States of America
# 0                                               Brazil
# 31                                               India
# 56                                               Spain
# 25                                              Russia
# 16                                    Northern America
# 106                                             Canada
# 47                                             Denmark
# 44                                           Australia
# 176  Western Electricity Coordinating Council, US p...
# 111                       SERC Reliability Corporation
# 174  Northeast Power Coordinating Council, US part ...
# 215                                               Asia
# 97                               Texas Regional Entity
# 166                       ReliabilityFirst Corporation
# 164                    Latin America and the Caribbean
# 237                              IAI Area, EU27 & EFTA
# 45      Midwest Reliability Organization, US part only
# 48                                                HICC
# 98                 Alaska Systems Coordinating Council
# 81                               Brazil, Southern grid
#
#                       Shortname   Latitude   Longitude  \
# 1                           GLO        NaN         NaN
# 6                           RER  59.970128   78.961769
# 8    Europe without Switzerland  48.597508    6.421103
# 13                           CN  33.420000  106.514000
# 15                           US  39.622000  -98.606000
# 0                            BR -10.772000  -53.089000
# 31                           IN  21.000000   78.500000
# 56                           ES  40.227000   -3.649000
# 25                           RU  61.847380   97.037378
# 16                          RNA  58.710600  -91.968294
# 106                          CA  59.081000 -109.433000
# 47                           DK  56.058000    9.264000
# 44                           AU -24.973000  136.189000
# 176                     US-WECC        NaN         NaN
# 111                     US-SERC  34.995137  -86.475241
# 174                     US-NPCC        NaN         NaN
# 215                         RAS  45.201180   96.075924
# 97                       US-TRE  30.917217  -99.212649
# 166                      US-RFC  40.811908  -82.239575
# 164                         RLA -10.119415  -65.624398
# 237       IAI Area, EU27 & EFTA        NaN         NaN
# 45                       US-MRO        NaN         NaN
# 48                      US-HICC  20.251901 -156.350435
# 98                      US-ASCC  60.532783 -143.141804
# 81             BR-Southern grid        NaN         NaN
#
#     Geography Classification  \
# 1                      World
# 6           ecoinvent Region
# 8      ecoinvent Custom Area
# 13                   Country
# 15                   Country
# 0                    Country
# 31                   Country
# 56                   Country
# 25                   Country
# 16              UN Subregion
# 106                  Country
# 47                   Country
# 44                   Country
# 176         Electricity Grid
# 111         Electricity Grid
# 174         Electricity Grid
# 215         ecoinvent Region
# 97          Electricity Grid
# 166         Electricity Grid
# 164             UN Subregion
# 237       Aluminium Industry
# 45          Electricity Grid
# 48          Electricity Grid
# 98          Electricity Grid
# 81          Electricity Grid
#
#                  Contained and Overlapping Geographies  Log Process Count  \
# 1    AD; AE; AF; AG; AI; Akrotiri; AL; AM; AO; AQ; ...           3.657438
# 6    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...           3.356599
# 8    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...           2.793092
# 13   China w/o Inner Mongol; CN-AH; CN-BJ; CN-CCG; ...           2.626340
# 15   MRO; NPCC; US-AK; US-AL; US-AR; US-ASCC; US-AZ...           2.514548
# 0    BR-AC; BR-AL; BR-AM; BR-AP; BR-BA; BR-CE; BR-D...           2.495544
# 31   IN-AN; IN-AP; IN-AR; IN-AS; IN-BR; IN-CH; IN-C...           2.429752
# 56                                      Canary Islands           2.232996
# 25   Asia without China; Europe without Austria; Eu...           2.071882
# 16   BM; CA; CA-AB; CA-BC; CA-MB; Canada without Al...           2.033424
# 106  CA-AB; CA-BC; CA-MB; Canada without Alberta; C...           2.017033
# 47   Europe without NORDEL (NCPA); NORDEL; UCTE; UC...           1.929419
# 44   AU-ACT; AU-JBT; AU-NSW; AU-NT; AU-QLD; AU-SA; ...           1.908485
# 176  MRO; US-AZ; US-CA; US-CO; US-ID; US-MT; US-NE;...           1.591065
# 111  US-AL; US-AR; US-FL; US-GA; US-IL; US-KY; US-L...           1.556303
# 174    US-CT; US-MA; US-ME; US-NH; US-NY; US-RI; US-VT           1.556303
# 215  AE; AF; Akrotiri; AM; Asia without China; AZ; ...           1.544068
# 97                                        US-OK; US-TX           1.518514
# 166  US-DC; US-DE; US-IL; US-IN; US-KY; US-MD; US-M...           1.518514
# 164  AG; AI; AR; AW; BB; BL; BO; BQ; BR; BR-AC; BR-...           1.505150
# 237  Canary Islands; CENTREL; DE; ES; Europe withou...           1.505150
# 45   US-AR; US-IA; US-IL; US-KS; US-LA; US-MN; US-M...           1.505150
# 48                                               US-HI           1.431364
# 98                                               US-AK           1.414973
# 81                                 BR-PR; BR-RS; BR-SC           1.361728
#
#     base_name                         Contained_Geographies_List
# 1        None  [AD, AE, AF, AG, AI, None, AL, AM, AO, AQ, AR,...
# 6        None  [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 8        None  [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 13         CN  [None, CN, CN, CN, CN, CN, CN, CN, CN, CN, CN,...
# 15         US  [None, None, US, US, US, US, US, US, US, US, U...
# 0          BR  [BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, B...
# 31         IN  [IN, IN, IN, IN, IN, IN, IN, IN, IN, IN, IN, I...
# 56         ES                                             [None]
# 25         RU  [None, None, None, None, None, None, None, Non...
# 16       None  [BM, CA, CA, CA, CA, None, None, None, CA, CA,...
# 106        CA  [CA, CA, CA, None, None, None, CA, CA, CA, CA,...
# 47         DK               [None, None, None, None, None, None]
# 44         AU               [AU, AU, AU, AU, AU, AU, AU, AU, AU]
# 176        US  [None, US, US, US, US, US, US, US, US, US, US,...
# 111        US  [US, US, US, US, US, US, US, US, US, US, US, U...
# 174        US                       [US, US, US, US, US, US, US]
# 215      None  [AE, AF, None, AM, None, AZ, BD, BH, BN, BT, N...
# 97         US                                           [US, US]
# 166        US  [US, US, US, US, US, US, US, US, US, US, US, U...
# 164      None  [AG, AI, AR, AW, BB, BL, BO, BQ, BR, BR, BR, B...
# 237      None  [None, None, DE, ES, None, None, FR, None, GB,...
# 45         US  [US, US, US, US, US, US, US, US, US, US, US, U...
# 48         US                                               [US]
# 98         US                                               [US]
# 81         BR                                       [BR, BR, BR]

# %% [markdown]
# There are two categories of contained geography here:
# * Those that **obscure** locality. For example, Europe except Switzerland is basically just Europe. It makes sense in opposition to Switzerland, but I don't think we should count it as local data for all the sub regions -- that is, add the process count to all the countries included. Instead, we'll just add it to the Europe category for the
# * Those that **enhance** locality. For example. All the regional electricity grids, such as India, Eastern grid. We need to bear these in mind when we are doing heatmap data or trying to subdivide countries. Otherwise, we can just take the sum and add it to the country as a whole to get a good indication of **national** level process counts.

# %%
## if the list column is all for sub-localities of the same place, we can just say that it's all for that place
def update_single_val(row):
    list_vals = row['Contained_Geographies_List']
    single_val = row['base_name']
    
    if single_val is None and len(set(list_vals)) == 1:
        row['single_col'] = list_vals[0]  # Update single_val to the value in the list
    return row

country_frame = country_frame.apply(update_single_val, axis=1)
country_frame.dropna(subset=['Contained and Overlapping Geographies']).sort_values(by='Process Count', ascending=False).head(25)
# Out:
#                  Contained and Overlapping Geographies  \
# 1    AD; AE; AF; AG; AI; Akrotiri; AL; AM; AO; AQ; ...
# 6    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 8    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 13   China w/o Inner Mongol; CN-AH; CN-BJ; CN-CCG; ...
# 15   MRO; NPCC; US-AK; US-AL; US-AR; US-ASCC; US-AZ...
# 0    BR-AC; BR-AL; BR-AM; BR-AP; BR-BA; BR-CE; BR-D...
# 31   IN-AN; IN-AP; IN-AR; IN-AS; IN-BR; IN-CH; IN-C...
# 56                                      Canary Islands
# 25   Asia without China; Europe without Austria; Eu...
# 16   BM; CA; CA-AB; CA-BC; CA-MB; Canada without Al...
# 106  CA-AB; CA-BC; CA-MB; Canada without Alberta; C...
# 47   Europe without NORDEL (NCPA); NORDEL; UCTE; UC...
# 44   AU-ACT; AU-JBT; AU-NSW; AU-NT; AU-QLD; AU-SA; ...
# 176  MRO; US-AZ; US-CA; US-CO; US-ID; US-MT; US-NE;...
# 111  US-AL; US-AR; US-FL; US-GA; US-IL; US-KY; US-L...
# 174    US-CT; US-MA; US-ME; US-NH; US-NY; US-RI; US-VT
# 215  AE; AF; Akrotiri; AM; Asia without China; AZ; ...
# 97                                        US-OK; US-TX
# 166  US-DC; US-DE; US-IL; US-IN; US-KY; US-MD; US-M...
# 164  AG; AI; AR; AW; BB; BL; BO; BQ; BR; BR-AC; BR-...
# 237  Canary Islands; CENTREL; DE; ES; Europe withou...
# 45   US-AR; US-IA; US-IL; US-KS; US-LA; US-MN; US-M...
# 48                                               US-HI
# 98                                               US-AK
# 81                                 BR-PR; BR-RS; BR-SC
#
#                             Contained_Geographies_List  \
# 1    [AD, AE, AF, AG, AI, None, AL, AM, AO, AQ, AR,...
# 6    [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 8    [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 13   [None, CN, CN, CN, CN, CN, CN, CN, CN, CN, CN,...
# 15   [None, None, US, US, US, US, US, US, US, US, U...
# 0    [BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, B...
# 31   [IN, IN, IN, IN, IN, IN, IN, IN, IN, IN, IN, I...
# 56                                              [None]
# 25   [None, None, None, None, None, None, None, Non...
# 16   [BM, CA, CA, CA, CA, None, None, None, CA, CA,...
# 106  [CA, CA, CA, None, None, None, CA, CA, CA, CA,...
# 47                [None, None, None, None, None, None]
# 44                [AU, AU, AU, AU, AU, AU, AU, AU, AU]
# 176  [None, US, US, US, US, US, US, US, US, US, US,...
# 111  [US, US, US, US, US, US, US, US, US, US, US, U...
# 174                       [US, US, US, US, US, US, US]
# 215  [AE, AF, None, AM, None, AZ, BD, BH, BN, BT, N...
# 97                                            [US, US]
# 166  [US, US, US, US, US, US, US, US, US, US, US, U...
# 164  [AG, AI, AR, AW, BB, BL, BO, BQ, BR, BR, BR, B...
# 237  [None, None, DE, ES, None, None, FR, None, GB,...
# 45   [US, US, US, US, US, US, US, US, US, US, US, U...
# 48                                                [US]
# 98                                                [US]
# 81                                        [BR, BR, BR]
#
#     Geography Classification                                    ID   Latitude  \
# 1                      World  34dbbff8-88ce-11de-ad60-0019e336be3a        NaN
# 6           ecoinvent Region  0723d252-7e2a-11de-9820-0019e336be3a  59.970128
# 8      ecoinvent Custom Area  f9221622-cc45-11de-98ed-0019e336be3a  48.597508
# 13                   Country  0c40fa1e-7d7e-11de-9ae2-0019e336be3a  33.420000
# 15                   Country  13d387f6-7d7e-11de-9ae2-0019e336be3a  39.622000
# 0                    Country  0a2c8c66-7d7e-11de-9ae2-0019e336be3a -10.772000
# 31                   Country  0e6a7860-7d7e-11de-9ae2-0019e336be3a  21.000000
# 56                   Country  12ea642c-7d7e-11de-9ae2-0019e336be3a  40.227000
# 25                   Country  12143bfe-7d7e-11de-9ae2-0019e336be3a  61.847380
# 16              UN Subregion  0fecb5e8-7e2a-11de-9820-0019e336be3a  58.710600
# 106                  Country  0b2a8a96-7d7e-11de-9ae2-0019e336be3a  59.081000
# 47                   Country  0cf950f0-7d7e-11de-9ae2-0019e336be3a  56.058000
# 44                   Country  09b1a988-7d7e-11de-9ae2-0019e336be3a -24.973000
# 176         Electricity Grid  f37ced82-5df8-48c2-a207-1e36dd11a112        NaN
# 111         Electricity Grid  a7b38401-afb6-4130-86f6-cd5184c6c40e  34.995137
# 174         Electricity Grid  50f826e7-ab13-444e-987b-180701b691c9        NaN
# 215         ecoinvent Region  19c7cdd2-e590-11de-9dfe-0019e336be3a  45.201180
# 97          Electricity Grid  854cdfab-82bf-4c25-8515-ba33589d3efe  30.917217
# 166         Electricity Grid  42e6cfaf-ffa3-4f42-85bb-55e1b1c40c56  40.811908
# 164             UN Subregion  09db3260-7e2a-11de-9820-0019e336be3a -10.119415
# 237       Aluminium Industry  b7fcfda9-0add-49aa-87d4-d60f3bda4283        NaN
# 45          Electricity Grid  6432879f-dc31-4e80-bc55-573f72dafee8        NaN
# 48          Electricity Grid  598f9aa4-e409-11de-bce5-0019e336be3a  20.251901
# 98          Electricity Grid  a9c3be27-affe-464c-8ebf-996d8ab6a958  60.532783
# 81          Electricity Grid  dd2330a8-30dc-4af9-bb3a-d2d2bf404dde        NaN
#
#      Log Process Count   Longitude  \
# 1             3.657438         NaN
# 6             3.356599   78.961769
# 8             2.793092    6.421103
# 13            2.626340  106.514000
# 15            2.514548  -98.606000
# 0             2.495544  -53.089000
# 31            2.429752   78.500000
# 56            2.232996   -3.649000
# 25            2.071882   97.037378
# 16            2.033424  -91.968294
# 106           2.017033 -109.433000
# 47            1.929419    9.264000
# 44            1.908485  136.189000
# 176           1.591065         NaN
# 111           1.556303  -86.475241
# 174           1.556303         NaN
# 215           1.544068   96.075924
# 97            1.518514  -99.212649
# 166           1.518514  -82.239575
# 164           1.505150  -65.624398
# 237           1.505150         NaN
# 45            1.505150         NaN
# 48            1.431364 -156.350435
# 98            1.414973 -143.141804
# 81            1.361728         NaN
#
#                                                   Name  Process Count  \
# 1                                               Global           4543
# 6                                               Europe           2272
# 8                           Europe without Switzerland            620
# 13                                               China            422
# 15                            United States of America            326
# 0                                               Brazil            312
# 31                                               India            268
# 56                                               Spain            170
# 25                                              Russia            117
# 16                                    Northern America            107
# 106                                             Canada            103
# 47                                             Denmark             84
# 44                                           Australia             80
# 176  Western Electricity Coordinating Council, US p...             38
# 111                       SERC Reliability Corporation             35
# 174  Northeast Power Coordinating Council, US part ...             35
# 215                                               Asia             34
# 97                               Texas Regional Entity             32
# 166                       ReliabilityFirst Corporation             32
# 164                    Latin America and the Caribbean             31
# 237                              IAI Area, EU27 & EFTA             31
# 45      Midwest Reliability Organization, US part only             31
# 48                                                HICC             26
# 98                 Alaska Systems Coordinating Council             25
# 81                               Brazil, Southern grid             22
#
#                       Shortname base_name  single_col
# 1                           GLO      None         NaN
# 6                           RER      None         NaN
# 8    Europe without Switzerland      None         NaN
# 13                           CN        CN         NaN
# 15                           US        US         NaN
# 0                            BR        BR         NaN
# 31                           IN        IN         NaN
# 56                           ES        ES         NaN
# 25                           RU        RU         NaN
# 16                          RNA      None         NaN
# 106                          CA        CA         NaN
# 47                           DK        DK         NaN
# 44                           AU        AU         NaN
# 176                     US-WECC        US         NaN
# 111                     US-SERC        US         NaN
# 174                     US-NPCC        US         NaN
# 215                         RAS      None         NaN
# 97                       US-TRE        US         NaN
# 166                      US-RFC        US         NaN
# 164                         RLA      None         NaN
# 237       IAI Area, EU27 & EFTA      None         NaN
# 45                       US-MRO        US         NaN
# 48                      US-HICC        US         NaN
# 98                      US-ASCC        US         NaN
# 81             BR-Southern grid        BR         NaN

# %%
cont_codes = pd.read_csv(f"{root}/Data/indexing_csvs/country-and-continent-codes-list.csv")
cont_codes
# Out:
#     Continent_Name Continent_Code  \
# 0             Asia             AS
# 1           Europe             EU
# 2       Antarctica             AN
# 3           Africa             AF
# 4          Oceania             OC
# ..             ...            ...
# 257         Africa             AF
# 258        Oceania             OC
# 259           Asia             AS
# 260           Asia             AS
# 261           Asia             AS
#
#                                      Country_Name Two_Letter_Country_Code  \
# 0                Afghanistan, Islamic Republic of                      AF
# 1                            Albania, Republic of                      AL
# 2    Antarctica (the territory South of 60 deg S)                      AQ
# 3        Algeria, People's Democratic Republic of                      DZ
# 4                                  American Samoa                      AS
# ..                                            ...                     ...
# 257                           Zambia, Republic of                      ZM
# 258                            Disputed Territory                      XX
# 259                Iraq-Saudi Arabia Neutral Zone                      XE
# 260                   United Nations Neutral Zone                      XD
# 261                               Spratly Islands                      XS
#
#     Three_Letter_Country_Code  Country_Number
# 0                         AFG             4.0
# 1                         ALB             8.0
# 2                         ATA            10.0
# 3                         DZA            12.0
# 4                         ASM            16.0
# ..                        ...             ...
# 257                       ZMB           894.0
# 258                       NaN             NaN
# 259                       NaN             NaN
# 260                       NaN             NaN
# 261                       NaN             NaN
#
# [262 rows x 6 columns]

# %%
country_frame[country_frame['Name'] == 'Europe']
# Out:
#                Contained and Overlapping Geographies  \
# 6  AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
#
#                           Contained_Geographies_List Geography Classification  \
# 6  [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...         ecoinvent Region
#
#                                      ID   Latitude  Log Process Count  \
# 6  0723d252-7e2a-11de-9820-0019e336be3a  59.970128           3.356599
#
#    Longitude    Name  Process Count Shortname base_name  single_col
# 6  78.961769  Europe           2272       RER      None         NaN

# %% [markdown]
# This looks good, so now we merge with an ISO sheet for continent and region indexing.

# %%
## First we merge with the named Continents directly
cont_codes = pd.read_csv(f"{root}/Data/indexing_csvs/country-and-continent-codes-list.csv")
conts_only = cont_codes['Continent_Name'].value_counts().reset_index().drop(columns='count')
cont_frame = pd.merge(
    left=country_frame,
    right=conts_only,
    left_on='Name',
    right_on='Continent_Name',
    how='inner'
)
cont_frame
# Out:
#                Contained and Overlapping Geographies  \
# 0  AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 1  AS; AU; AU-ACT; AU-JBT; AU-NSW; AU-NT; AU-QLD;...
# 2  AE; AF; Akrotiri; AM; Asia without China; AZ; ...
# 3  AO; BF; BI; BJ; BW; CD; CF; CG; CM; CV; DJ; DZ...
#
#                           Contained_Geographies_List Geography Classification  \
# 0  [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...         ecoinvent Region
# 1  [AS, AU, AU, AU, AU, AU, AU, AU, AU, AU, AU, C...                UN Region
# 2  [AE, AF, None, AM, None, AZ, BD, BH, BN, BT, N...         ecoinvent Region
# 3  [AO, BF, BI, BJ, BW, CD, CF, CG, CM, CV, DJ, D...                UN Region
#
#                                      ID   Latitude  Log Process Count  \
# 0  0723d252-7e2a-11de-9820-0019e336be3a  59.970128           3.356599
# 1  9232290c-e62b-11de-ba56-0019e336be3a -25.282887           1.322219
# 2  19c7cdd2-e590-11de-9dfe-0019e336be3a  45.201180           1.544068
# 3  2f693dc6-7e28-11de-9820-0019e336be3a   6.417882           1.000000
#
#     Longitude     Name  Process Count   Shortname base_name  single_col  \
# 0   78.961769   Europe           2272         RER      None         NaN
# 1  136.406721  Oceania             20  UN-OCEANIA        UN         NaN
# 2   96.075924     Asia             34         RAS      None         NaN
# 3   18.287021   Africa              9         RAF      None         NaN
#
#   Continent_Name
# 0         Europe
# 1        Oceania
# 2           Asia
# 3         Africa

# %%
## Now we merge with the basenames, dropping those that don't have a basename
country_frame_redux = pd.merge(
    left=country_frame.dropna(subset=['base_name']),
    right=cont_codes,
    left_on='base_name',
    right_on='Two_Letter_Country_Code',
    how='left'
)
country_frame_redux.sort_values(by='Process Count', ascending=False).head(4)
# Out:
#                 Contained and Overlapping Geographies  \
# 5                                                 NaN
# 10  China w/o Inner Mongol; CN-AH; CN-BJ; CN-CCG; ...
# 25                                                NaN
# 13  MRO; NPCC; US-AK; US-AL; US-AR; US-ASCC; US-AZ...
#
#                            Contained_Geographies_List  \
# 5                                              [None]
# 10  [None, CN, CN, CN, CN, CN, CN, CN, CN, CN, CN,...
# 25                                             [None]
# 13  [None, None, US, US, US, US, US, US, US, US, U...
#
#    Geography Classification                                    ID   Latitude  \
# 5                   Country  131278d6-7d7e-11de-9ae2-0019e336be3a  46.861000
# 10                  Country  0c40fa1e-7d7e-11de-9ae2-0019e336be3a  33.420000
# 25        Province or State  868a66d1-7428-4ba2-9125-253b07afc119  53.390446
# 13                  Country  13d387f6-7d7e-11de-9ae2-0019e336be3a  39.622000
#
#     Log Process Count   Longitude                      Name  Process Count  \
# 5            3.433130    7.908000               Switzerland           2710
# 10           2.626340  106.514000                     China            422
# 25           2.624282  -71.755869            Canada, Québec            420
# 13           2.514548  -98.606000  United States of America            326
#
#    Shortname base_name  single_col Continent_Name Continent_Code  \
# 5         CH        CH         NaN         Europe             EU
# 10        CN        CN         NaN           Asia             AS
# 25     CA-QC        CA         NaN  North America            NaN
# 13        US        US         NaN  North America            NaN
#
#                         Country_Name Two_Letter_Country_Code  \
# 5   Switzerland, Swiss Confederation                      CH
# 10       China, People's Republic of                      CN
# 25                            Canada                      CA
# 13          United States of America                      US
#
#    Three_Letter_Country_Code  Country_Number
# 5                        CHE           756.0
# 10                       CHN           156.0
# 25                       CAN           124.0
# 13                       USA           840.0

# %%
## Get those countries who don't connect and remove them.

unlabeled = country_frame[country_frame['base_name'].isna()].sort_values(by='Process Count', ascending=False)
unlabeled[unlabeled['Process Count'] > 15]
# Out:
#                  Contained and Overlapping Geographies  \
# 2                                                  NaN
# 1    AD; AE; AF; AG; AI; Akrotiri; AL; AM; AO; AQ; ...
# 6    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 8    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 16   BM; CA; CA-AB; CA-BC; CA-MB; Canada without Al...
# 55                                                 NaN
# 215  AE; AF; Akrotiri; AM; Asia without China; AZ; ...
# 237  Canary Islands; CENTREL; DE; ES; Europe withou...
# 164  AG; AI; AR; AW; BB; BL; BO; BQ; BR; BR-AC; BR-...
# 170  CA-AB; CA-BC; CA-MB; Canada without Alberta; C...
#
#                             Contained_Geographies_List  \
# 2                                               [None]
# 1    [AD, AE, AF, AG, AI, None, AL, AM, AO, AQ, AR,...
# 6    [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 8    [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 16   [BM, CA, CA, CA, CA, None, None, None, CA, CA,...
# 55                                              [None]
# 215  [AE, AF, None, AM, None, AZ, BD, BH, BN, BT, N...
# 237  [None, None, DE, ES, None, None, FR, None, GB,...
# 164  [AG, AI, AR, AW, BB, BL, BO, BQ, BR, BR, BR, B...
# 170  [CA, CA, CA, None, None, CA, CA, CA, CA, CA, C...
#
#     Geography Classification                                    ID   Latitude  \
# 2      ecoinvent Custom Area  7846b897-7c04-4f9f-b607-2b83fcd9a74c        NaN
# 1                      World  34dbbff8-88ce-11de-ad60-0019e336be3a        NaN
# 6           ecoinvent Region  0723d252-7e2a-11de-9820-0019e336be3a  59.970128
# 8      ecoinvent Custom Area  f9221622-cc45-11de-98ed-0019e336be3a  48.597508
# 16              UN Subregion  0fecb5e8-7e2a-11de-9820-0019e336be3a  58.710600
# 55     ecoinvent Custom Area  81e54bf8-5993-5b5b-bc50-6978cab0c51f        NaN
# 215         ecoinvent Region  19c7cdd2-e590-11de-9dfe-0019e336be3a  45.201180
# 237       Aluminium Industry  b7fcfda9-0add-49aa-87d4-d60f3bda4283        NaN
# 164             UN Subregion  09db3260-7e2a-11de-9820-0019e336be3a -10.119415
# 170    ecoinvent Custom Area  a4d7d7fd-94ae-4f44-91ba-53cd7f79bac4        NaN
#
#      Log Process Count  Longitude                             Name  \
# 2             3.669689        NaN                    Rest-of-World
# 1             3.657438        NaN                           Global
# 6             3.356599  78.961769                           Europe
# 8             2.793092   6.421103       Europe without Switzerland
# 16            2.033424 -91.968294                 Northern America
# 55            1.806180        NaN                   Rest of Europe
# 215           1.544068  96.075924                             Asia
# 237           1.505150        NaN            IAI Area, EU27 & EFTA
# 164           1.505150 -65.624398  Latin America and the Caribbean
# 170           1.230449        NaN            Canada without Quebec
#
#      Process Count                   Shortname base_name  single_col
# 2             4673                         RoW      None         NaN
# 1             4543                         GLO      None         NaN
# 6             2272                         RER      None         NaN
# 8              620  Europe without Switzerland      None         NaN
# 16             107                         RNA      None         NaN
# 55              63                         RoE      None         NaN
# 215             34                         RAS      None         NaN
# 237             31       IAI Area, EU27 & EFTA      None         NaN
# 164             31                         RLA      None         NaN
# 170             16       Canada without Quebec      None         NaN

# %%
## Some of them we have to just label by hand
mappings = {
    'Rest-of-World': 'Global',
    'global': 'Global',
    'Europe without Switzerland': 'Europe',
    'Canada without Quebec': 'North America',
    'Rest of Europe': 'Europe',
    'Northern America': 'North America',
    'Latin America and the Caribbean': 'South America'

}

unlabeled['Continent_Name'] = unlabeled['Name'].map(mappings)

# %%
country_frame_merged_cont = pd.concat([unlabeled, country_frame_redux, cont_frame], axis=0, ignore_index=True)

print(country_frame.shape, country_frame_merged_cont.shape)
# Out:
# (331, 12) (342, 18)

# %%
country_frame_merged_cont
# Out:
#                  Contained and Overlapping Geographies  \
# 0                                                  NaN
# 1    AD; AE; AF; AG; AI; Akrotiri; AL; AM; AO; AQ; ...
# 2    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 3    AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 4    BM; CA; CA-AB; CA-BC; CA-MB; Canada without Al...
# ..                                                 ...
# 337                                                NaN
# 338  AD; AL; AT; AX; BA; BALTSO; BE; BG; BY; Canary...
# 339  AS; AU; AU-ACT; AU-JBT; AU-NSW; AU-NT; AU-QLD;...
# 340  AE; AF; Akrotiri; AM; Asia without China; AZ; ...
# 341  AO; BF; BI; BJ; BW; CD; CF; CG; CM; CV; DJ; DZ...
#
#                             Contained_Geographies_List  \
# 0                                               [None]
# 1    [AD, AE, AF, AG, AI, None, AL, AM, AO, AQ, AR,...
# 2    [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 3    [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 4    [BM, CA, CA, CA, CA, None, None, None, CA, CA,...
# ..                                                 ...
# 337                                             [None]
# 338  [AD, AL, AT, AX, BA, None, BE, BG, BY, None, N...
# 339  [AS, AU, AU, AU, AU, AU, AU, AU, AU, AU, AU, C...
# 340  [AE, AF, None, AM, None, AZ, BD, BH, BN, BT, N...
# 341  [AO, BF, BI, BJ, BW, CD, CF, CG, CM, CV, DJ, D...
#
#     Geography Classification                                    ID   Latitude  \
# 0      ecoinvent Custom Area  7846b897-7c04-4f9f-b607-2b83fcd9a74c        NaN
# 1                      World  34dbbff8-88ce-11de-ad60-0019e336be3a        NaN
# 2           ecoinvent Region  0723d252-7e2a-11de-9820-0019e336be3a  59.970128
# 3      ecoinvent Custom Area  f9221622-cc45-11de-98ed-0019e336be3a  48.597508
# 4               UN Subregion  0fecb5e8-7e2a-11de-9820-0019e336be3a  58.710600
# ..                       ...                                   ...        ...
# 337                  Country  129718da-7d7e-11de-9ae2-0019e336be3a  -1.998000
# 338         ecoinvent Region  0723d252-7e2a-11de-9820-0019e336be3a  59.970128
# 339                UN Region  9232290c-e62b-11de-ba56-0019e336be3a -25.282887
# 340         ecoinvent Region  19c7cdd2-e590-11de-9dfe-0019e336be3a  45.201180
# 341                UN Region  2f693dc6-7e28-11de-9820-0019e336be3a   6.417882
#
#      Log Process Count   Longitude                        Name  Process Count  \
# 0             3.669689         NaN               Rest-of-World           4673
# 1             3.657438         NaN                      Global           4543
# 2             3.356599   78.961769                      Europe           2272
# 3             2.793092    6.421103  Europe without Switzerland            620
# 4             2.033424  -91.968294            Northern America            107
# ..                 ...         ...                         ...            ...
# 337           0.301030   29.917000                      Rwanda              1
# 338           3.356599   78.961769                      Europe           2272
# 339           1.322219  136.406721                     Oceania             20
# 340           1.544068   96.075924                        Asia             34
# 341           1.000000   18.287021                      Africa              9
#
#                       Shortname base_name  single_col Continent_Name  \
# 0                           RoW      None         NaN         Global
# 1                           GLO      None         NaN            NaN
# 2                           RER      None         NaN            NaN
# 3    Europe without Switzerland      None         NaN         Europe
# 4                           RNA      None         NaN  North America
# ..                          ...       ...         ...            ...
# 337                          RW        RW         NaN         Africa
# 338                         RER      None         NaN         Europe
# 339                  UN-OCEANIA        UN         NaN        Oceania
# 340                         RAS      None         NaN           Asia
# 341                         RAF      None         NaN         Africa
#
#     Continent_Code         Country_Name Two_Letter_Country_Code  \
# 0              NaN                  NaN                     NaN
# 1              NaN                  NaN                     NaN
# 2              NaN                  NaN                     NaN
# 3              NaN                  NaN                     NaN
# 4              NaN                  NaN                     NaN
# ..             ...                  ...                     ...
# 337             AF  Rwanda, Republic of                      RW
# 338            NaN                  NaN                     NaN
# 339            NaN                  NaN                     NaN
# 340            NaN                  NaN                     NaN
# 341            NaN                  NaN                     NaN
#
#     Three_Letter_Country_Code  Country_Number
# 0                         NaN             NaN
# 1                         NaN             NaN
# 2                         NaN             NaN
# 3                         NaN             NaN
# 4                         NaN             NaN
# ..                        ...             ...
# 337                       RWA           646.0
# 338                       NaN             NaN
# 339                       NaN             NaN
# 340                       NaN             NaN
# 341                       NaN             NaN
#
# [342 rows x 18 columns]

# %%
country_frame_merged_cont['Two_Letter_Country_Code'].value_counts()
# Out:
# Two_Letter_Country_Code
# CN    40
# IN    39
# BR    32
# US    26
# CA    14
#       ..
# JP     1
# UA     1
# HU     1
# NI     1
# RW     1
# Name: count, Length: 144, dtype: int64

# %%
# country_frame_combined.sort_values(by='Process Count_summed', ascending=False)

# %% [markdown]
# #### Figures

# %%
# Stacked histogram with hue for coloring
sns.histplot(
    data=country_frame_merged_cont,
    x=country_frame_merged_cont['Log Process Count'],  # Log-transform
    hue='Continent_Name',                                 
    multiple='stack',                                 
    bins=30,
    palette='Set2'                                  
)

# Labels and title
plt.xlabel(r"$\log_{10}$ Process Count")
plt.ylabel("Country Count")
plt.title("Histogram of ecoinvent 3.11 Cutoff Localization by Continent")
legend = plt.gca().get_legend() 
legend.set_title('Continent') 


plt.savefig(f"{root}/Figures/Basic_Viz/Line and Bargraphs/ecoinvent_localization_hist.png", bbox_inches='tight')

plt.show()

# %%
# Stacked histogram with hue for coloring
sns.histplot(
    data=country_frame_redux,
    x=country_frame_redux['Log Process Count'],  # Log-transform
    hue='Continent_Name',                                 
    multiple='stack',                                 
    bins=30,
    palette='Set2'                                  
)

# Labels and title
plt.xlabel(r"$\log_{10}$ Process Count")
plt.ylabel("Country Count")
plt.title("Histogram of ecoinvent 3.11 Cutoff Localization by Continent with Country Level Data Only")
legend = plt.gca().get_legend() 
legend.set_title('Continent') 

plt.savefig(f"{root}/Figures/Basic_Viz/Line and Bargraphs/ecoinvent_localization_hist_country_only.png", bbox_inches='tight')

plt.show()

# %%
continent_frame = country_frame_merged_cont.groupby(country_frame_merged_cont['Continent_Name'])['Process Count'].sum().reset_index()
sns.barplot(data=continent_frame, x='Continent_Name', y='Process Count')
plt.xlabel("")
plt.title("Process Count in ecoinvent 3.11 Cutoff by Continent")
plt.xticks(rotation=45)
plt.savefig(f"{root}/Figures/Basic_Viz/Line and Bargraphs/Process_count_by_continent.png")
plt.show()

# %% [markdown]
# ### Economic Plots

# %%
gdp_frame = pd.read_csv(f"{root}/Data/indexing_csvs/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_88.csv")

# %% [markdown]
# In order to make the gdp make sense we need to conglomerate all the territory process counts

# %%
# Grouping by 'Two_Letter_Country_Code' and summing 'Process Count'
country_frame_merged_cont_grouped = (
    country_frame_merged_cont
    .groupby('Two_Letter_Country_Code', as_index=False)['Process Count']
    .sum()
)

# Merging the grouped sums back to the original DataFrame
country_frame_merged_cont_grouped = country_frame_merged_cont.merge(
    country_frame_merged_cont_grouped[['Two_Letter_Country_Code', 'Process Count']], 
    on='Two_Letter_Country_Code', 
    how='left', 
    suffixes=('', '_summed')
)

# Creating 'Log Process Count' as the log10 of the summed 'Process Count'
country_frame_merged_cont_grouped['Log Process Count_summed'] = np.log10(
    country_frame_merged_cont_grouped['Process Count_summed']
)

country_frame_combined = country_frame_merged_cont_grouped.groupby('Two_Letter_Country_Code', as_index=False).agg({
    'Process Count_summed': 'mean',  # Summing 'Process Count'
    'Log Process Count_summed': 'mean'  # Optionally, taking the mean of 'Log Process Count' or another aggregation
})

country_frame_merged_cont_grouped = country_frame_merged_cont_grouped.drop_duplicates(
    subset='Two_Letter_Country_Code', 
    keep='first'
)

# %%
country_frame_merged_cont_grouped.sort_values(by='Process Count_summed', ascending=False)
# Out:
#                  Contained and Overlapping Geographies  \
# 36                                                 NaN
# 31   BR-AC; BR-AL; BR-AM; BR-AP; BR-BA; BR-CE; BR-D...
# 41   China w/o Inner Mongol; CN-AH; CN-BJ; CN-CCG; ...
# 56                                                 NaN
# 44   MRO; NPCC; US-AK; US-AL; US-AR; US-ASCC; US-AZ...
# ..                                                 ...
# 254                                                NaN
# 324                                                NaN
# 315  AD; AT; AX; BA; BALTSO; BE; BG; Canary Islands...
# 337                                                NaN
# 0                                                  NaN
#
#                             Contained_Geographies_List  \
# 36                                              [None]
# 31   [BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, B...
# 41   [None, CN, CN, CN, CN, CN, CN, CN, CN, CN, CN,...
# 56                                              [None]
# 44   [None, None, US, US, US, US, US, US, US, US, U...
# ..                                                 ...
# 254                                             [None]
# 324                                             [None]
# 315  [AD, AT, AX, BA, None, BE, BG, None, None, CH,...
# 337                                             [None]
# 0                                               [None]
#
#     Geography Classification                                    ID   Latitude  \
# 36                   Country  131278d6-7d7e-11de-9ae2-0019e336be3a  46.861000
# 31                   Country  0a2c8c66-7d7e-11de-9ae2-0019e336be3a -10.772000
# 41                   Country  0c40fa1e-7d7e-11de-9ae2-0019e336be3a  33.420000
# 56         Province or State  868a66d1-7428-4ba2-9125-253b07afc119  53.390446
# 44                   Country  13d387f6-7d7e-11de-9ae2-0019e336be3a  39.622000
# ..                       ...                                   ...        ...
# 254                  Country  098771a4-7d7e-11de-9ae2-0019e336be3a -12.296000
# 324                  Country  11663ae0-7d7e-11de-9ae2-0019e336be3a  -5.949000
# 315         Electricity Grid  f87aa98c-d820-11de-a736-0019e336be3a        NaN
# 337                  Country  129718da-7d7e-11de-9ae2-0019e336be3a  -1.998000
# 0      ecoinvent Custom Area  7846b897-7c04-4f9f-b607-2b83fcd9a74c        NaN
#
#      Log Process Count   Longitude  \
# 36            3.433130    7.908000
# 31            2.495544  -53.089000
# 41            2.626340  106.514000
# 56            2.624282  -71.755869
# 44            2.514548  -98.606000
# ..                 ...         ...
# 254           0.845098   17.544000
# 324           0.778151  143.459000
# 315           0.602060         NaN
# 337           0.301030   29.917000
# 0             3.669689         NaN
#
#                                                   Name  Process Count  \
# 36                                         Switzerland           2710
# 31                                              Brazil            312
# 41                                               China            422
# 56                                      Canada, Québec            420
# 44                            United States of America            326
# ..                                                 ...            ...
# 254                                             Angola              6
# 324                                   Papua New Guinea              5
# 315  European Network of Transmission Systems Opera...              3
# 337                                             Rwanda              1
# 0                                        Rest-of-World           4673
#
#     Shortname base_name  single_col Continent_Name Continent_Code  \
# 36         CH        CH         NaN         Europe             EU
# 31         BR        BR         NaN  South America             SA
# 41         CN        CN         NaN           Asia             AS
# 56      CA-QC        CA         NaN  North America            NaN
# 44         US        US         NaN  North America            NaN
# ..        ...       ...         ...            ...            ...
# 254        AO        AO         NaN         Africa             AF
# 324        PG        PG         NaN        Oceania             OC
# 315   ENTSO-E        SO         NaN         Africa             AF
# 337        RW        RW         NaN         Africa             AF
# 0         RoW      None         NaN         Global            NaN
#
#                                Country_Name Two_Letter_Country_Code  \
# 36         Switzerland, Swiss Confederation                      CH
# 31           Brazil, Federative Republic of                      BR
# 41              China, People's Republic of                      CN
# 56                                   Canada                      CA
# 44                 United States of America                      US
# ..                                      ...                     ...
# 254                     Angola, Republic of                      AO
# 324  Papua New Guinea, Independent State of                      PG
# 315                Somalia, Somali Republic                      SO
# 337                     Rwanda, Republic of                      RW
# 0                                       NaN                     NaN
#
#     Three_Letter_Country_Code  Country_Number  Process Count_summed  \
# 36                        CHE           756.0                2710.0
# 31                        BRA            76.0                 994.0
# 41                        CHN           156.0                 983.0
# 56                        CAN           124.0                 845.0
# 44                        USA           840.0                 643.0
# ..                        ...             ...                   ...
# 254                       AGO            24.0                   6.0
# 324                       PNG           598.0                   5.0
# 315                       SOM           706.0                   3.0
# 337                       RWA           646.0                   1.0
# 0                         NaN             NaN                   NaN
#
#      Log Process Count_summed
# 36                   3.432969
# 31                   2.997386
# 41                   2.992554
# 56                   2.926857
# 44                   2.808211
# ..                        ...
# 254                  0.778151
# 324                  0.698970
# 315                  0.477121
# 337                  0.000000
# 0                         NaN
#
# [145 rows x 20 columns]

# %%
merged_gdp = pd.merge(
    left=country_frame_merged_cont_grouped,
    right=gdp_frame,
    left_on='Three_Letter_Country_Code',
    right_on='Country Code',
    how='inner',
)

merged_gdp['log_gdp'] = np.log10(merged_gdp['2022'])
merged_gdp
# Out:
#                  Contained and Overlapping Geographies  \
# 0    BR-AC; BR-AL; BR-AM; BR-AP; BR-BA; BR-CE; BR-D...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
#
#                             Contained_Geographies_List  \
# 0    [BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, BR, B...
# 1                                               [None]
# 2                                               [None]
# 3                                               [None]
# 4                                               [None]
# ..                                                 ...
# 138                                             [None]
# 139                                             [None]
# 140                                             [None]
# 141                                             [None]
# 142                                             [None]
#
#     Geography Classification                                    ID  Latitude  \
# 0                    Country  0a2c8c66-7d7e-11de-9ae2-0019e336be3a   -10.772
# 1                    Country  0f515f00-7d7e-11de-9ae2-0019e336be3a    48.707
# 2                    Country  11387d6c-7d7e-11de-9ae2-0019e336be3a    -9.326
# 3                    Country  12b21766-7d7e-11de-9ae2-0019e336be3a   -30.558
# 4                    Country  131278d6-7d7e-11de-9ae2-0019e336be3a    46.861
# ..                       ...                                   ...       ...
# 138                  Country  14266b60-7d7e-11de-9ae2-0019e336be3a   -32.800
# 139                  Country  0f0215a8-7d7e-11de-9ae2-0019e336be3a    39.778
# 140                  Country  11663ae0-7d7e-11de-9ae2-0019e336be3a    -5.949
# 141                  Country  0eed3c64-7d7e-11de-9ae2-0019e336be3a    18.151
# 142                  Country  129718da-7d7e-11de-9ae2-0019e336be3a    -1.998
#
#      Log Process Count  Longitude              Name  Process Count Shortname  \
# 0             2.495544    -53.089            Brazil            312        BR
# 1             2.000000     19.491          Slovakia             99        SK
# 2             2.250420    -75.552              Peru            177        PE
# 3             2.474216     23.121      South Africa            297        ZA
# 4             3.433130      7.908       Switzerland           2710        CH
# ..                 ...        ...               ...            ...       ...
# 138           0.954243    -56.012           Uruguay              8        UY
# 139           0.845098    126.451       North Korea              6        KP
# 140           0.778151    143.459  Papua New Guinea              5        PG
# 141           0.845098    -77.320           Jamaica              6        JM
# 142           0.301030     29.917            Rwanda              1        RW
#
#      ...          2016          2017          2018          2019  \
# 0    ...  1.795693e+12  2.063515e+12  1.916934e+12  1.873288e+12
# 1    ...  9.034717e+10  9.597813e+10  1.066117e+11  1.058435e+11
# 2    ...  1.918981e+11  2.110080e+11  2.225970e+11  2.283460e+11
# 3    ...  3.235855e+11  3.814488e+11  4.052607e+11  3.893300e+11
# 4    ...  6.878955e+11  6.952008e+11  7.255687e+11  7.213691e+11
# ..   ...           ...           ...           ...           ...
# 138  ...  5.748079e+10  6.500604e+10  6.534458e+10  6.222233e+10
# 139  ...           NaN           NaN           NaN           NaN
# 140  ...  2.075888e+10  2.274270e+10  2.410978e+10  2.475063e+10
# 141  ...  1.407710e+10  1.480899e+10  1.573079e+10  1.583077e+10
# 142  ...  8.695272e+09  9.252834e+09  9.637905e+09  1.034930e+10
#
#              2020          2021          2022          2023  Unnamed: 68  \
# 0    1.476107e+12  1.670647e+12  1.951924e+12  2.173666e+12          NaN
# 1    1.077326e+11  1.205922e+11  1.159286e+11  1.329083e+11          NaN
# 2    2.014097e+11  2.263543e+11  2.464888e+11  2.676032e+11          NaN
# 3    3.379747e+11  4.208869e+11  4.069200e+11  3.806993e+11          NaN
# 4    7.419994e+11  8.134088e+11  8.184266e+11  8.849404e+11          NaN
# ..            ...           ...           ...           ...          ...
# 138  5.366864e+10  6.076080e+10  7.016468e+10  7.724083e+10          NaN
# 139           NaN           NaN           NaN           NaN          NaN
# 140  2.384845e+10  2.610941e+10  3.164728e+10  3.072924e+10          NaN
# 141  1.381242e+10  1.465759e+10  1.709776e+10  1.942336e+10          NaN
# 142  1.017439e+10  1.106928e+10  1.331616e+10  1.409777e+10          NaN
#
#        log_gdp
# 0    12.290463
# 1    11.064191
# 2    11.391797
# 3    11.609509
# 4    11.912980
# ..         ...
# 138  10.846119
# 139        NaN
# 140  10.500336
# 141  10.232939
# 142  10.124379
#
# [143 rows x 90 columns]

# %%
sns.scatterplot(data=merged_gdp, y='Log Process Count_summed', x='log_gdp', hue='Continent_Name')
plt.title("Log-Log Relationship Between Process Counts and GDP")
plt.ylabel(r"$\log_{10}$ Process Count")
plt.xlabel(r"$\log_{10}$ GDP in 2022")
legend = plt.gca().get_legend() 
legend.set_title('Continent') 
plt.savefig(f"{root}/Figures/Basic_Viz/Line and Bargraphs/GDP_Process_Scatterplot.svg", format="svg")
plt.show()

# %% [markdown]
# ### Geomapping
#
# #### Load in Shapefiles

# %%
states = gpd.read_file(f"{root}/Data/Shapefiles/Natural_earth_states_provinces_all/ne_10m_admin_1_states_provinces.shp")
states.head(3)
# Out:
#                  featurecla  scalerank adm1_code  diss_me iso_3166_2  \
# 0  Admin-1 states provinces          3  ARG-1309     1309       AR-E
# 1  Admin-1 states provinces          6     URY-8        8      UY-PA
# 2  Admin-1 states provinces          2  IDN-1185     1185      ID-KI
#
#   wikipedia iso_a2  adm0_sr              name    name_alt  ... FCLASS_ID  \
# 0      None     AR        1        Entre Ríos  Entre-Rios  ...      None
# 1      None     UY        1          Paysandú        None  ...      None
# 2      None     ID        5  Kalimantan Timur      Kaltim  ...      None
#
#   FCLASS_PL FCLASS_GR FCLASS_IT FCLASS_NL FCLASS_SE FCLASS_BD FCLASS_UA  \
# 0      None      None      None      None      None      None      None
# 1      None      None      None      None      None      None      None
# 2      None      None      None      None      None      None      None
#
#   FCLASS_TLC                                           geometry
# 0       None  POLYGON ((-58.20011 -32.44713, -58.20012 -32.4...
# 1       None  POLYGON ((-58.20012 -32.4472, -58.20011 -32.44...
# 2       None  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
#
# [3 rows x 122 columns]

# %%
countries = gpd.read_file(f"{root}/Data/Shapefiles/Natural_earth_countries_all/ne_10m_admin_0_countries.shp")
# for col in countries.columns:
#     print(col)
countries[countries['ISO_A2'] == 'US']


## Using this commented code we figure out that norway and france, as well as some dispute countries, don't have ISO codes. As we'll use these for merging, 
## we just manually fix them. 
# problem_rows = countries[countries['ISO_A2'] == '-99']
# print(problem_rows[['NAME', 'ISO_A2', 'ISO_A3']])

fixes = {
    'France': {'ISO_A2': 'FR', 'ISO_A3': 'FRA'},
    'Norway': {'ISO_A2': 'NO', 'ISO_A3': 'NOR'},
    'Kosovo': {'ISO_A2': 'XK', 'ISO_A3': 'XKX'},       
    'Somaliland': {'ISO_A2': 'SO', 'ISO_A3': 'SOL'},   
}

for name, codes in fixes.items():
    countries.loc[countries['NAME'] == name, ['ISO_A2', 'ISO_A3']] = codes['ISO_A2'], codes['ISO_A3']

# %%
## get all the non-country territories 
matched_territories = pd.merge(
    left = country_frame_merged_cont,
    right = states,
    how = 'inner',
    left_on = 'Shortname',
    right_on = 'iso_3166_2'
)

# countries_left = country_frame_merged_cont[~country_frame_merged_cont['Shortname'].isin(matched_territories['Shortname'])]
# countries_left

## get all the country-level territories
matched_countries = pd.merge(
    left = country_frame_merged_cont,
    right = countries,
    how = 'inner',
    left_on = 'Two_Letter_Country_Code',
    right_on = 'ISO_A2'
)

# ## for a final frame, un-localize the territory level processes to the country-level
# grouped = matched_territories.groupby(matched_territories['Shortname'].str[:2])['Process Count'].sum().reset_index() ## add the 
# matched_added = pd.merge(
#     matched_countries, grouped, on='Shortname', how='outer', suffixes=('_df1', '_df2'))
# matched_added
# matched_added['Process Count'] = matched_added['Process Count_df1'].fillna(0) + matched_added['Process Count_df2'].fillna(0)


## for a final frame, un-localize the territory level processes to the country-level using the model we used for GDP
country_frame_merged_cont_grouped_gdf = pd.merge(
    left = country_frame_merged_cont_grouped,
    right = countries,
    how = 'inner',
    left_on='Two_Letter_Country_Code',
    right_on='ISO_A2'
)

# %%
## set up a dictionary, convert everything to coordinates
frames = {
    "country-level processes in ecoinvent 3.11 cutoff technosphere" : matched_countries,
    "territory-level processes in ecoinvent 3.11 cutoff technosphere" : matched_territories,
    # "all processes in ecoinvent 3.11 cutoff technosphere, with territory specific rolled into countries" : matched_added,
    "all processes in ecoinvent 3.11 cutoff technosphere, with territory specific rolled into countries": country_frame_merged_cont_grouped_gdf
}

for name, frame in frames.items():
    frame = gpd.GeoDataFrame(frame, geometry='geometry')
    frame.set_crs('EPSG:4326', allow_override=True, inplace=True)
    frames[name] = frame

# %% [markdown]
# #### Geographic Heatmaps

# %%
def plot_heatmap_frame(frame, ax, col='Process Count'):
    # Get colors and plot them
    ax.axis("off")
    cm = mpl.colormaps.get_cmap("YlOrRd")
    norm = mpl.colors.LogNorm(vmin=1, vmax=10**4)

    ## Dynamic Norming (left for posterity)
    # norm = mpl.colors.LogNorm(vmin=frame['Process Count'].min(), vmax=frame['Process Count'].max())

    print(col)
    frame.plot(column=col, norm=norm, cmap=cm, ax=ax,
               edgecolor='black',
                linewidth = 0.3 )
    
    countries = gpd.read_file(f"{root}/Data/Shapefiles/Natural_earth_countries_all/ne_10m_admin_0_countries.shp")
    countries = countries[countries['NAME'] != 'Antarctica']
    countries.boundary.plot(ax=ax, edgecolor='gray', linewidth=0.2)

    
    ## Dynamic Colorbar 
    sm = plt.cm.ScalarMappable(cmap=cm, norm=norm)
    sm._A = []  
    cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.0)
    cbar.set_label('Process Count')

# %%
    # countries = gpd.read_file(f"{root}/Data/Shapefiles/Natural_earth_countries_all/ne_10m_admin_0_countries.shp")
    # countries = countries[countries['NAME'] != 'Antarctica']

# %%
i = 0
for name, frame in frames.items():
        if i < 2:
                col = "Process Count" 
        else:
                col="Process Count_summed"
        fig, ax = plt.subplots(1, figsize=(14, 16))
        plot_heatmap_frame(frame, ax, col=col)
        plt.title(f"Heatmap for {name}", fontsize=16)
        plt.tight_layout() 
        plt.savefig(f"{root}/Figures/Basic_Viz/Heatmaps/{name}.svg",  bbox_inches='tight', format="svg")
        i += 1
# Out:
# Process Count
# Process Count
# Process Count_summed
